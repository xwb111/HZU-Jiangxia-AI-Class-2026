# %% [markdown]
# # 正向传播、反向传播和计算图

# %% [markdown]
# 正向传播指的是神经网络从输入层到输出层，逐层计算每个节点的输出值的过程。反向传播指的是神经网络从输出层到输入层，逐层计算每个节点的误差项，并根据误差项更新每个节点的权重和偏置的过程。
#
# 计算图是一种用于表示神经网络中各个节点之间的计算关系的图。在计算图中，每个节点代表一个计算操作，每条边代表一个输入或输出关系。通过计算图，可以清晰地表示神经网络的结构和计算过程，方便进行正向传播和反向传播的计算。

# %% [markdown]
# 训练深度学习模型
#
# 正常传播和反向传播相互依赖，不能单独使用。
