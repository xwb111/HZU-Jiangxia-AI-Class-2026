# %%
class Dog:
    role='dog'
    def __init__(self,name,breed,attack_val):
        self.name=name
        self.breed=breed
        self.attack_val=attack_val
        self.life_val=100
    def bite(self,person):
        person.life_val-=self.attack_val
        print('狗[%s]咬了人[%s],人掉血[%s],还剩血量[%s]'%(self.name,person.name,self.attack_val,person.life_val))

# %%
class Person:
    role='person'
    def __init__(self,name,sex,atack_val):
        self.name=name
        self.sex=sex
        self.attack_val=atack_val
        self.life_val=100
    def attack(self,dog):
        dog.life_val-=self.attack_val
        print('人[%s]打了狗[%s],狗掉血[%s],还剩血量[%s]'%(self.name,dog.name,self.attack_val,dog.life_val))

# %%
p1=Person('mark','男' ,50)
d1=Dog('jjj','金毛',50)
p1.attack(d1)
d1.bite(p1)
# Out:
# 人[mark]打了狗[jjj],狗掉血[50],还剩血量[50]
# 狗[jjj]咬了人[mark],人掉血[50],还剩血量[50]
